# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import time
from tesserocr import PyTessBaseAPI
import os
from PIL import Image
import json
import string
import pandas as pd

# %%
img1 = cv2.imread(r"C:\Users\brans\OneDrive\Documents\Application-files-utilities\VScode\Project-007\TemplateModeAlphaTesting\Template.jpg")
img2 = cv2.imread(r"C:\Users\brans\OneDrive\Documents\Application-files-utilities\VScode\Project-007\TemplateModeAlphaTesting\Data\Data1.jpg")

# %%
print(img1.shape[0], img1.shape[1])
thresh = cv2.resize(img2, (img1.shape[1], img1.shape[0]))
# Out:
# 3300 2550

# %%
print(img1.shape)
plt.imshow(img1)
# Out:
# (3300, 2550, 3)

# %%
print(img2.shape)
plt.imshow(img2)
# Out:
# (1650, 1275, 3)

# %%
print(thresh.shape)
plt.imshow(thresh)
# Out:
# (3300, 2550, 3)
